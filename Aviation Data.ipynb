# %%
#import the required libraries
import numpy as np
import pandas as pd
import urllib

# %%
dataset = pd.read_csv('data/AviationData.csv', delimiter=',')
dataset.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20170601X43457             Accident        GAA17CA313    05/31/2017
# 1  20170531X12547             Accident        GAA17CA312    05/30/2017
# 2  20170531X31309             Accident        GAA17CA309    05/30/2017
# 3  20170530X03313             Accident        GAA17CA308    05/27/2017
# 4  20170526X85142             Accident        GAA17CA305    05/26/2017
#
#         Location          Country     Latitude      Longitude   Airport Code   \
# 0     Clovis~ NM    United States                                        CVN
# 1   El Cajon~ CA    United States    32.826111    -116.972500            SEE
# 2    Peyette~ ID    United States    44.094444    -116.903611            S75
# 3   Lakeside~ TX    United States    32.814167     -97.553333
# 4    Develan~ CA    United States
#
#        Airport Name  ...  Air Carrier   Total Fatal Injuries   \
# 0                    ...
# 1   GILLESPIE FIELD  ...
# ...

# %%
dataset.describe()
# Out:
#               Event Id   Investigation Type   Accident Number    Event Date   \
# count             79954                79954             79954         79954
# unique            78792                    2             79954         12795
# top     20100204X45658             Accident        ERA09CA006    05/16/1982
# freq                  3                76733                 1            25
#
#               Location          Country   Latitude   Longitude   \
# count             79954            79954      79954       79954
# unique            25434              178      18020       19323
# top      ANCHORAGE~ AK    United States
# freq                372            75282      53624       53633
#
#         Airport Code   Airport Name   ...    Air Carrier   \
# count           79954          79954  ...           79954
# unique           9702          22917  ...            2894
# top                                   ...
# freq            34741          30113  ...           76004
#
# ...

# %%
dataset.tail()
# Out:
#              Event Id   Investigation Type   Accident Number    Event Date   \
# 79949  20041105X01764             Accident        CHI79FA064    08/02/1979
# 79950  20001218X45448             Accident        LAX96LA321    06/19/1977
# 79951  20061025X01555             Accident        NYC07LA005    08/30/1974
# 79952  20001218X45447             Accident        LAX94LA336    07/19/1962
# 79953  20001218X45444             Accident        SEA87LA080    10/24/1948
#
#                Location          Country     Latitude     Longitude   \
# 79949        Canton~ OH    United States
# 79950        EUREKA~ CA    United States
# 79951     Saltville~ VA    United States    36.922223    -81.878056
# 79952    BRIDGEPORT~ CA    United States
# 79953   MOOSE CREEK~ ID    United States
#
#        Airport Code   Airport Name  ...  Air Carrier   Total Fatal Injuries   \
# 79949                               ...                                   1
# ...
